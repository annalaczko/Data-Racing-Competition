# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
readIn = pd.read_csv("training_data.csv")
df = pd.DataFrame(readIn)

# %%
readIn = pd.read_csv("data_submission_example.csv")
df_target = pd.DataFrame(readIn)
df_target.head(20)
# Out:
#    BORROWER_ID      PRED
# 0     +++b/oYx  0.014477
# 1     +++pcjqH  0.014477
# 2     +++ukYrT  0.014477
# 3     +++wvYn7  0.014477
# 4     ++/6JzSJ  0.014477
# 5     ++/Ys2ls  0.014477
# 6     ++/faYdJ  0.014477
# 7     ++/rT+Iv  0.014477
# 8     ++0Mv31Z  0.014477
# 9     ++0yhZwt  0.014477
# 10    ++1P//5Z  0.014477
# 11    ++1ZnHPw  0.014477
# 12    ++2NJSkx  0.014477
# 13    ++2cmBBi  0.014477
# 14    ++3rMqJj  0.014477
# 15    ++40SB0B  0.014477
# 16    ++47oOSs  0.014477
# 17    ++4LpXo1  0.014477
# 18    ++4YWhkL  0.014477
# 19    ++5SEXuh  0.014477

# %%
df.head(10)
# Out:
#   CONTRACT_ID BORROWER_ID CONTRACT_BANK_ID  CONTRACT_CREDIT_INTERMEDIARY  \
# 0    TpK8osXs    d8SqtuEV         1d42bbf5                           2.0
# 1    EtIEHrcH    lrdxML0g         1d42bbf5                           NaN
# 2    1G10DfKj    gII7nnq4         1d42bbf5                           2.0
# 3     2NLT774    MMkJ8z/e         1d42bbf5                           NaN
# 4    VpylRvay    M417onFP         1d42bbf5                           2.0
# 5    5tsDwTjS    u9GRAuen         1d42bbf5                           2.0
# 6    drZAWXaR    XPWFcJZI         1d42bbf5                           NaN
# 7     ebtK6u+    L2Nu2zZe         1d42bbf5                           2.0
# 8     ffJh4MY    5A0GWOi2         1d42bbf5                           2.0
# 9    eo09vYuo    lqPGd2+x         1d42bbf5                           2.0
#
#    CONTRACT_CREDIT_LOSS  CONTRACT_CURRENCY  CONTRACT_DATE_OF_LOAN_AGREEMENT  \
# 0                   0.0                 31                          2457052
# 1                   0.0                 31                          2457036
# 2               16350.0                 31                          2457043
# 3                   0.0                 31                          2457038
# 4                2395.0                 31                          2457091
# 5                   0.0                 31                          2457093
# 6                   0.0                 31                          2457095
# 7                   0.0                 31                          2457046
# 8                   0.0                 31                          2457049
# 9                   0.0                 31                          2457081
#
#    CONTRACT_DEPT_SERVICE_TO_INCOME CONTRACT_FREQUENCY_TYPE  CONTRACT_INCOME  \
# 0                              NaN                479a2e13              NaN
# 1                              NaN                479a2e13              NaN
# 2                             7.05                479a2e13         127305.0
# 3                              NaN                479a2e13              NaN
# 4                              NaN                479a2e13              NaN
# 5                              NaN                479a2e13              NaN
# 6                            33.94                479a2e13         172647.0
# 7                              NaN                479a2e13              NaN
# 8                              NaN                479a2e13              NaN
# 9                              NaN                479a2e13              NaN
#
#    ...  CONTRACT_RISK_WEIGHTED_ASSETS  CONTRACT_TYPE_OF_INTEREST_REPAYMENT  \
# 0  ...                           1.00                                  NaN
# 1  ...                          74.17                                  NaN
# 2  ...                          74.77                             100003.0
# 3  ...                           0.99                                  NaN
# 4  ...                          74.30                             100002.0
# 5  ...                           0.98                                  NaN
# 6  ...                           1.00                                  NaN
# 7  ...                           1.03                                  NaN
# 8  ...                           1.04                                  NaN
# 9  ...                           1.00                                  0.0
#
#    BORROWER_BIRTH_YEAR  BORROWER_CITIZENSHIP  BORROWER_COUNTRY  \
# 0               1217.0                  98.0              98.0
# 1                  NaN                   NaN               NaN
# 2               1199.0                  98.0              98.0
# 3               1221.0                  98.0              98.0
# 4               1260.0                  98.0              98.0
# 5               1204.0                  98.0              98.0
# 6                  NaN                   NaN               NaN
# 7               1255.0                  98.0              98.0
# 8               1234.0                  98.0              98.0
# 9               1228.0                  98.0              98.0
#
#    BORROWER_COUNTY  BORROWER_TYPE_OF_CUSTOMER  BORROWER_TYPE_OF_SETTLEMENT  \
# 0             20.0                          A                          NaN
# 1              NaN                          A                          NaN
# 2            179.0                          A                          7.0
# 3              NaN                          A                          NaN
# 4            178.0                          A                          1.0
# 5              NaN                          A                          NaN
# 6              NaN                          A                          NaN
# 7              4.0                          A                          NaN
# 8              NaN                          A                          NaN
# 9              3.0                          A                          NaN
#
#   TARGET_EVENT  TARGET_EVENT_DAY
# 0            -               NaN
# 1            -               NaN
# 2            -               NaN
# 3            -               NaN
# 4            -               NaN
# 5            -               NaN
# 6            -               NaN
# 7            -               NaN
# 8            -               NaN
# 9            -               NaN
#
# [10 rows x 34 columns]

# %%
data_count=len(df)

# %%
data_count
# Out:
# 1602753

# %%
non_nan_rows = df.dropna(subset=['CONTRACT_INSTALMENT_AMOUNT', 'CONTRACT_INSTALMENT_AMOUNT_2'])
#print(len(non_nan_rows))

cols=['CONTRACT_INSTALMENT_AMOUNT', 'CONTRACT_INSTALMENT_AMOUNT_2']

non_df= non_nan_rows[cols].head(20)

non_df['arany']=non_df['CONTRACT_INSTALMENT_AMOUNT']/non_df['CONTRACT_INSTALMENT_AMOUNT_2']

cols=['CONTRACT_INSTALMENT_AMOUNT', 'CONTRACT_INSTALMENT_AMOUNT_2', 'arany']

non_df[cols].head(20)
# Out:
#     CONTRACT_INSTALMENT_AMOUNT  CONTRACT_INSTALMENT_AMOUNT_2     arany
# 0                       9545.0                       11059.0  0.863098
# 2                       8899.0                        8880.0  1.002140
# 3                      14329.0                       12966.0  1.105121
# 4                       4003.0                        3901.0  1.026147
# 5                      11214.0                       10727.0  1.045399
# 7                      11405.0                       11423.0  0.998424
# 8                       6045.0                        6008.0  1.006158
# 9                      10431.0                       10420.0  1.001056
# 10                     14638.0                       15437.0  0.948241
# 11                     11677.0                       11513.0  1.014245
# 12                     16536.0                       16630.0  0.994348
# 14                     10478.0                        9745.0  1.075218
# 16                      8739.0                        8700.0  1.004483
# 17                     17708.0                       16726.0  1.058711
# 18                      8039.0                        7960.0  1.009925
# 19                      8039.0                        7960.0  1.009925
# 20                      8752.0                        8818.0  0.992515
# 21                     25639.0                       26383.0  0.971800
# 22                     18515.0                       19220.0  0.963319
# 23                     18045.0                       18048.0  0.999834

# %%
coloumns=[
    'CONTRACT_ID',
    'BORROWER_ID',
    'CONTRACT_BANK_ID',
    'CONTRACT_CREDIT_INTERMEDIARY',
    'CONTRACT_CREDIT_LOSS',
    'CONTRACT_CURRENCY',
    'CONTRACT_DATE_OF_LOAN_AGREEMENT',
    'CONTRACT_DEPT_SERVICE_TO_INCOME',
    'CONTRACT_FREQUENCY_TYPE',
    'CONTRACT_INCOME',
    'CONTRACT_INSTALMENT_AMOUNT',
    'CONTRACT_INSTALMENT_AMOUNT_2',
    'CONTRACT_INTEREST_PERIOD',
    'CONTRACT_INTEREST_RATE',
    'CONTRACT_LGD',
    'CONTRACT_LOAN_AMOUNT',
    'CONTRACT_LOAN_CONTRACT_TYPE',
    'CONTRACT_LOAN_TO_VALUE_RATIO',
    'CONTRACT_LOAN_TYPE',
    'CONTRACT_MARKET_VALUE',
    'CONTRACT_MATURITY_DATE',
    'CONTRACT_MORTGAGE_LENDING_VALUE',
    'CONTRACT_MORTGAGE_TYPE',
    'CONTRACT_REFINANCED',
    'CONTRACT_RISK_WEIGHTED_ASSETS',
    'CONTRACT_TYPE_OF_INTEREST_REPAYMENT',
    'BORROWER_BIRTH_YEAR',
    'BORROWER_CITIZENSHIP',
    'BORROWER_COUNTRY',
    'BORROWER_COUNTY',
    'BORROWER_TYPE_OF_CUSTOMER',
    'BORROWER_TYPE_OF_SETTLEMENT',
    'TARGET_EVENT',
    'TARGET_EVENT_DAY'
]

# coloumns=[
#     'CONTRACT_ID',
#     'BORROWER_ID',
#     'CONTRACT_BANK_ID',
#     'CONTRACT_CREDIT_LOSS',
#     'CONTRACT_CURRENCY',
#     'CONTRACT_DATE_OF_LOAN_AGREEMENT',
#     'CONTRACT_FREQUENCY_TYPE',
#     'CONTRACT_LOAN_AMOUNT',
#     'CONTRACT_LOAN_CONTRACT_TYPE',
#     'CONTRACT_LOAN_TYPE',
#     'CONTRACT_MATURITY_DATE',
#     'BORROWER_TYPE_OF_CUSTOMER',
#     'TARGET_EVENT'
# ]

# %%
df=df[coloumns]

# %% [markdown]
# # Data preparation

# %% [markdown]
# ## Coloumns

# %% [markdown]
# ### ISNA

# %%
df.isna().sum()
# Out:
# CONTRACT_ID                                  0
# BORROWER_ID                                  0
# CONTRACT_BANK_ID                             0
# CONTRACT_CREDIT_INTERMEDIARY             59422
# CONTRACT_CREDIT_LOSS                     36154
# CONTRACT_CURRENCY                            0
# CONTRACT_DATE_OF_LOAN_AGREEMENT              0
# CONTRACT_DEPT_SERVICE_TO_INCOME         201480
# CONTRACT_FREQUENCY_TYPE                      0
# CONTRACT_INCOME                         198022
# CONTRACT_INSTALMENT_AMOUNT             1314531
# CONTRACT_INSTALMENT_AMOUNT_2             42438
# CONTRACT_INTEREST_PERIOD                371312
# CONTRACT_INTEREST_RATE                   35370
# CONTRACT_LGD                             33722
# CONTRACT_LOAN_AMOUNT                         0
# CONTRACT_LOAN_CONTRACT_TYPE                  0
# CONTRACT_LOAN_TO_VALUE_RATIO           1176530
# CONTRACT_LOAN_TYPE                           0
# CONTRACT_MARKET_VALUE                  1074843
# CONTRACT_MATURITY_DATE                       0
# CONTRACT_MORTGAGE_LENDING_VALUE        1064936
# CONTRACT_MORTGAGE_TYPE                 1064936
# CONTRACT_REFINANCED                      59422
# CONTRACT_RISK_WEIGHTED_ASSETS            33722
# CONTRACT_TYPE_OF_INTEREST_REPAYMENT     232962
# BORROWER_BIRTH_YEAR                      42867
# BORROWER_CITIZENSHIP                     42867
# BORROWER_COUNTRY                         42867
# BORROWER_COUNTY                          96677
# BORROWER_TYPE_OF_CUSTOMER                    0
# BORROWER_TYPE_OF_SETTLEMENT             528624
# TARGET_EVENT                                 0
# TARGET_EVENT_DAY                       1548364
# dtype: int64

# %% [markdown]
# ### CONTRACT_ID

# %% [markdown]
# ### BORROWER_ID

# %%
df['BORROWER_ID'].value_counts()
# Out:
# BORROWER_ID
# xNullx      1090
# akvNVipI      24
# qW3B+pgb      22
# 95IQewTL      19
# JARtY3P1      18
#             ...
# LqRn3EsW       1
# odaCvCmO       1
# seFkKZ2U       1
# WJWtceMu       1
# Dxng1cGs       1
# Name: count, Length: 1149851, dtype: int64

# %%
cols= [
    'BORROWER_ID',
    'CONTRACT_INCOME',
    'BORROWER_BIRTH_YEAR',
    'BORROWER_CITIZENSHIP',
    'BORROWER_COUNTRY',
    'BORROWER_COUNTY',
    'BORROWER_TYPE_OF_CUSTOMER',
    'BORROWER_TYPE_OF_SETTLEMENT',
]

df_borrower=df[cols]

df_borrower=df_borrower.drop_duplicates()

print(df_borrower.duplicated().value_counts())

print(len(df_borrower['BORROWER_ID'].unique()))

df_b2=df_borrower.duplicated()

print(df_borrower.isna().sum())
# Out:
# False    1595246
# Name: count, dtype: int64
# 1149851
# BORROWER_ID                         0
# CONTRACT_INCOME                192145
# BORROWER_BIRTH_YEAR             40757
# BORROWER_CITIZENSHIP            40757
# BORROWER_COUNTRY                40757
# BORROWER_COUNTY                 94503
# BORROWER_TYPE_OF_CUSTOMER           0
# BORROWER_TYPE_OF_SETTLEMENT    522319
# dtype: int64

# %%
cols= [
    'BORROWER_ID',
    'CONTRACT_INCOME',
    #'BORROWER_BIRTH_YEAR',
    'BORROWER_CITIZENSHIP',
    'BORROWER_COUNTRY',
    'BORROWER_COUNTY',
    'BORROWER_TYPE_OF_CUSTOMER',
    'BORROWER_TYPE_OF_SETTLEMENT'
]

df_borrower['BORROWER_BIRTH_YEAR'] = df.groupby('BORROWER_ID')['BORROWER_BIRTH_YEAR'].transform(lambda x: x.fillna(x.mean()))

df_borrower = df_borrower.sort_values(by='BORROWER_ID', ascending=True)

print(df_borrower.duplicated().value_counts())

df_borrower
# Out:
# False    1595246
# Name: count, dtype: int64
#         BORROWER_ID  CONTRACT_INCOME  BORROWER_BIRTH_YEAR  \
# 192167     +++b/oYx         405165.0               1257.0
# 1373556    +++pcjqH              0.0               1260.0
# 984427     +++ukYrT          94702.0               1222.0
# 30615      +++wvYn7              NaN               1260.0
# 917438     ++/6JzSJ         221782.0               1254.0
# ...             ...              ...                  ...
# 1462859    zzzUlMwd          98725.0               1226.0
# 521425     zzzf5tKU         373798.0               1233.0
# 314590     zzzjSsQj         116514.0               1241.0
# 932445     zzzwyh7V         379497.0               1257.0
# 1597684    zzzwyh7V              NaN               1257.0
#
#          BORROWER_CITIZENSHIP  BORROWER_COUNTRY  BORROWER_COUNTY  \
# 192167                   98.0              98.0             87.0
# 1373556                  98.0              98.0            112.0
# 984427                   98.0              98.0            133.0
# 30615                    98.0              98.0            189.0
# 917438                   98.0              98.0            124.0
# ...                       ...               ...              ...
# 1462859                  98.0              98.0            184.0
# 521425                   98.0              98.0             15.0
# 314590                   98.0              98.0             53.0
# 932445                   98.0              98.0             30.0
# 1597684                   NaN               NaN              NaN
#
#         BORROWER_TYPE_OF_CUSTOMER  BORROWER_TYPE_OF_SETTLEMENT
# 192167                          B                          0.0
# 1373556                         B                          3.0
# 984427                          A                          NaN
# 30615                           A                          NaN
# 917438                          A                          3.0
# ...                           ...                          ...
# 1462859                         A                          4.0
# 521425                          A                          4.0
# 314590                          A                          4.0
# 932445                          A                          3.0
# 1597684                         A                          NaN
#
# [1595246 rows x 8 columns]

# %%
df_borrower.isna().sum()
# Out:
# BORROWER_ID                         0
# CONTRACT_INCOME                192145
# BORROWER_BIRTH_YEAR             13528
# BORROWER_CITIZENSHIP            40757
# BORROWER_COUNTRY                40757
# BORROWER_COUNTY                 94503
# BORROWER_TYPE_OF_CUSTOMER           0
# BORROWER_TYPE_OF_SETTLEMENT    522319
# dtype: int64

# %%
df_borrower['BORROWER_CITIZENSHIP'] = df.groupby('BORROWER_ID')['BORROWER_CITIZENSHIP'].transform(lambda x: x.fillna(x.max()))

# %%
df_borrower.isna().sum()
# Out:
# BORROWER_ID                         0
# CONTRACT_INCOME                192145
# BORROWER_BIRTH_YEAR             13528
# BORROWER_CITIZENSHIP            13528
# BORROWER_COUNTRY                40757
# BORROWER_COUNTY                 94503
# BORROWER_TYPE_OF_CUSTOMER           0
# BORROWER_TYPE_OF_SETTLEMENT    522319
# dtype: int64

# %%
df_borrower['BORROWER_COUNTRY'] = df.groupby('BORROWER_ID')['BORROWER_COUNTRY'].transform(lambda x: x.fillna(x.max()))
df_borrower['BORROWER_COUNTY'] = df.groupby('BORROWER_ID')['BORROWER_COUNTY'].transform(lambda x: x.fillna(x.max()))

# %%
df_borrower.isna().sum()

df_borrower['CONTRACT_INCOME'] = df.groupby('BORROWER_ID')['CONTRACT_INCOME'].transform(lambda x: x.fillna(x.mean()))

# %%
df_borrower.isna().sum()
# Out:
# BORROWER_ID                         0
# CONTRACT_INCOME                112154
# BORROWER_BIRTH_YEAR             13528
# BORROWER_CITIZENSHIP            13528
# BORROWER_COUNTRY                13528
# BORROWER_COUNTY                 39090
# BORROWER_TYPE_OF_CUSTOMER           0
# BORROWER_TYPE_OF_SETTLEMENT    522319
# dtype: int64

# %% [markdown]
# ### BORROWER_BIRTH_YEAR

# %% [markdown]
# ### BORROWER_CITIZENSHIP

# %% [markdown]
# ### BORROWER_COUNTRY

# %%
df['BORROWER_COUNTRY'].value_counts()
# Out:
# BORROWER_COUNTRY
# 98.0     1559221
# 187.0        188
# 199.0        143
# 225.0         49
# 108.0         35
# 162.0         32
# 406.0         31
# 188.0         28
# 228.0         27
# 55.0          14
# 175.0         14
# 194.0          8
# 180.0          8
# 75.0           5
# 220.0          5
# 100.0          5
# 73.0           4
# 143.0          4
# 36.0           4
# 41.0           4
# 197.0          4
# 111.0          4
# 3.0            3
# 131.0          3
# 103.0          2
# 207.0          2
# 174.0          2
# 173.0          2
# 190.0          2
# 236.0          2
# 150.0          2
# 153.0          2
# 57.0           2
# 53.0           2
# 218.0          2
# 13.0           2
# 120.0          2
# 163.0          2
# 241.0          1
# 229.0          1
# 112.0          1
# 106.0          1
# 132.0          1
# 105.0          1
# 169.0          1
# 11.0           1
# 54.0           1
# 133.0          1
# 192.0          1
# 135.0          1
# 160.0          1
# 170.0          1
# 195.0          1
# Name: count, dtype: int64

# %% [markdown]
# ### BORROWER_COUNTY

# %%
df['BORROWER_COUNTY'].value_counts()
# Out:
# BORROWER_COUNTY
# 120.0    39679
# 189.0    34549
# 171.0    32164
# 2.0      26953
# 6.0      26858
#          ...
# 63.0      1867
# 110.0     1757
# 36.0      1737
# 61.0      1693
# 162.0     1618
# Name: count, Length: 199, dtype: int64

# %% [markdown]
# ### BORROWER_TYPE_OF_CUSTOMER

# %% [markdown]
# ### BORROWER_TYPE_OF_SETTLEMENT

# %% [markdown]
# ### CONTRACT_BANK_ID

# %%
df['CONTRACT_BANK_ID'].value_counts()
# Out:
# CONTRACT_BANK_ID
# 1d42bbf5    553874
# caa130b5    229117
# bd940aa2    133187
# f789f8b0    131126
# 2c6f5579     99995
#              ...
# 10b110f3         5
# d4cdedfe         5
# 85764f78         4
# 95e75ed5         2
# e9e18710         2
# Name: count, Length: 136, dtype: int64

# %% [markdown]
# ### CONTRACT_CREDIT_INTERMEDIARY

# %% [markdown]
# ### CONTRACT_CREDIT_LOSS

# %% [markdown]
# ### CONTRACT_CURRENCY

# %%
df['CONTRACT_CURRENCY'].value_counts()
# Out:
# CONTRACT_CURRENCY
# 31    1602691
# 24         37
# 14         25
# Name: count, dtype: int64

# %% [markdown]
# ### CONTRACT_DATE_OF_LOAN_AGREEMENT

# %% [markdown]
# ### CONTRACT_DEPT_SERVICE_TO_INCOME

# %%
df['CONTRACT_DEPT_SERVICE_TO_INCOME'].value_counts()
# Out:
# CONTRACT_DEPT_SERVICE_TO_INCOME
# 0.00      37284
# 49.46       646
# 49.43       629
# 49.47       625
# 49.41       613
#           ...
# 82.06         1
# 66.51         1
# 171.89        1
# 93.07         1
# 112.13        1
# Name: count, Length: 11367, dtype: int64

# %% [markdown]
# ### CONTRACT_FREQUENCY_TYPE

# %%
df['CONTRACT_FREQUENCY_TYPE'].value_counts()
# Out:
# CONTRACT_FREQUENCY_TYPE
# 479a2e13    1477500
# 2f88e16c      58702
# 87db11f5      47152
# 3265c5b7      17386
# ad534644       1616
# 89efd382        337
# 2aebe4cb         53
# bd092d5a          7
# Name: count, dtype: int64

# %%
df['CONTRACT_FREQUENCY_TYPE'].hist(bins=50)
plt.show()

# %% [markdown]
# ### CONTRACT_INCOME

# %%
df['CONTRACT_INCOME'].value_counts()
# Out:
# CONTRACT_INCOME
# 0.0         39179
# 1.0           518
# 2.0            51
# 85821.0        21
# 85214.0        21
#             ...
# 595553.0        1
# 493575.0        1
# 273729.0        1
# 316621.0        1
# 414567.0        1
# Name: count, Length: 410880, dtype: int64

# %%
df['CONTRACT_INCOME'].hist(bins=50)
plt.show()

# %%
cols=['CONTRACT_DEPT_SERVICE_TO_INCOME','CONTRACT_INCOME', 'CONTRACT_LOAN_AMOUNT' ]

df[cols].head(20)
# Out:
#     CONTRACT_DEPT_SERVICE_TO_INCOME  CONTRACT_INCOME  CONTRACT_LOAN_AMOUNT
# 0                               NaN              NaN                192161
# 1                               NaN              NaN                 55590
# 2                              7.05         127305.0                275924
# 3                               NaN              NaN                138862
# 4                               NaN              NaN                169624
# 5                               NaN              NaN                100079
# 6                             33.94         172647.0                338415
# 7                               NaN              NaN                140975
# 8                               NaN              NaN                 60963
# 9                               NaN              NaN                190782
# 10                              NaN              NaN                130827
# 11                            10.74         109235.0                307046
# 12                            40.93         107658.0                505557
# 13                              NaN              NaN                180016
# 14                              NaN              NaN                204978
# 15                              NaN              NaN                 96493
# 16                              NaN              NaN                100000
# 17                              NaN              NaN                172605
# 18                              NaN              NaN                 71570
# 19                              NaN              NaN                 71570

# %% [markdown]
# ### CONTRACT_INSTALMENT_AMOUNT and _2

# %%
df['CONTRACT_INSTALMENT_AMOUNT'].value_counts()
# Out:
# CONTRACT_INSTALMENT_AMOUNT
# 0.0          25856
# 9917.0          33
# 8708.0          32
# 9912.0          31
# 9940.0          31
#              ...
# 69197.0          1
# 45869.0          1
# 1767859.0        1
# 56375.0          1
# 418.0            1
# Name: count, Length: 61334, dtype: int64

# %%
df['CONTRACT_INSTALMENT_AMOUNT_2'].value_counts()
# Out:
# CONTRACT_INSTALMENT_AMOUNT_2
# 0.0          50214
# 9926.0         113
# 9934.0         113
# 9985.0         109
# 9902.0         107
#              ...
# 181434.0         1
# 79471.0          1
# 267987.0         1
# 1435741.0        1
# 146483.0         1
# Name: count, Length: 158047, dtype: int64

# %% [markdown]
# ### CONTRACT_INTEREST_PERIOD

# %% [markdown]
# ### CONTRACT_INTEREST_RATE

# %%
df['CONTRACT_INTEREST_RATE'].value_counts()
# Out:
# CONTRACT_INTEREST_RATE
# 0.00     110269
# 6.13       3223
# 6.08       3176
# 6.11       3102
# 6.10       3088
#           ...
# 39.32         1
# 42.01         1
# 94.86         1
# 63.31         1
# 37.97         1
# Name: count, Length: 4322, dtype: int64

# %%
df['CONTRACT_INTEREST_RATE'].hist(bins=100)
plt.show()

# %% [markdown]
# ### CONTRACT_LGD

# %% [markdown]
# ### CONTRACT_LOAN_AMOUNT

# %% [markdown]
# ### CONTRACT_LOAN_CONTRACT_TYPE

# %% [markdown]
# ### CONTRACT_LOAN_TO_VALUE_RATIO

# %% [markdown]
# ### CONTRACT_LOAN_TYPE

# %%
df['CONTRACT_LOAN_TYPE'].value_counts()
# Out:
# CONTRACT_LOAN_TYPE
# b503a0de    1008064
# 1f951336     157973
# d3aaffde      90930
# 7e2065f4      88126
# 69f70539      68104
# 2f88e16c      58702
# 955ae3ef      57006
# cf07c2dd      36335
# 5a06241e      21028
# 83910425       6920
# 694cbaee       3497
# 0aeb4094       2764
# eab72d7a       2310
# 95c4f8fb        571
# f792971b        240
# cde77491        106
# 47693941         74
# 8fe006f1          3
# Name: count, dtype: int64

# %% [markdown]
# ### CONTRACT_MARKET_VALUE

# %%
df['CONTRACT_MARKET_VALUE'].value_counts()
# Out:
# CONTRACT_MARKET_VALUE
# 0.0           32583
# 1.0              67
# 4.0              54
# 2.0              21
# 6914608.0        15
#               ...
# 3057979.0         1
# 5045813.0         1
# 22187871.0        1
# 19447135.0        1
# 532230.0          1
# Name: count, Length: 274389, dtype: int64

# %% [markdown]
# ### CONTRACT_MATURITY_DATE

# %% [markdown]
# ### CONTRACT_MORTGAGE_LENDING_VALUE

# %% [markdown]
# ### CONTRACT_MORTGAGE_TYPE

# %% [markdown]
# ### CONTRACT_REFINANCED

# %% [markdown]
# ### CONTRACT_RISK_WEIGHTED_ASSETS

# %% [markdown]
# ### CONTRACT_TYPE_OF_INTEREST_REPAYMENT

# %% [markdown]
# ### TARGET_EVENT_DAY

# %% [markdown]
# ### TARGET_EVENT

# %% [markdown]
# ### Check ISNA

# %%
df.head(10)
# Out:
#   CONTRACT_ID BORROWER_ID CONTRACT_BANK_ID  CONTRACT_CREDIT_INTERMEDIARY  \
# 0    TpK8osXs    d8SqtuEV         1d42bbf5                           2.0
# 1    EtIEHrcH    lrdxML0g         1d42bbf5                           NaN
# 2    1G10DfKj    gII7nnq4         1d42bbf5                           2.0
# 3     2NLT774    MMkJ8z/e         1d42bbf5                           NaN
# 4    VpylRvay    M417onFP         1d42bbf5                           2.0
# 5    5tsDwTjS    u9GRAuen         1d42bbf5                           2.0
# 6    drZAWXaR    XPWFcJZI         1d42bbf5                           NaN
# 7     ebtK6u+    L2Nu2zZe         1d42bbf5                           2.0
# 8     ffJh4MY    5A0GWOi2         1d42bbf5                           2.0
# 9    eo09vYuo    lqPGd2+x         1d42bbf5                           2.0
#
#    CONTRACT_CREDIT_LOSS  CONTRACT_CURRENCY  CONTRACT_DATE_OF_LOAN_AGREEMENT  \
# 0                   0.0                 31                          2457052
# 1                   0.0                 31                          2457036
# 2               16350.0                 31                          2457043
# 3                   0.0                 31                          2457038
# 4                2395.0                 31                          2457091
# 5                   0.0                 31                          2457093
# 6                   0.0                 31                          2457095
# 7                   0.0                 31                          2457046
# 8                   0.0                 31                          2457049
# 9                   0.0                 31                          2457081
#
#    CONTRACT_DEPT_SERVICE_TO_INCOME CONTRACT_FREQUENCY_TYPE  CONTRACT_INCOME  \
# 0                              NaN                479a2e13              NaN
# 1                              NaN                479a2e13              NaN
# 2                             7.05                479a2e13         127305.0
# 3                              NaN                479a2e13              NaN
# 4                              NaN                479a2e13              NaN
# 5                              NaN                479a2e13              NaN
# 6                            33.94                479a2e13         172647.0
# 7                              NaN                479a2e13              NaN
# 8                              NaN                479a2e13              NaN
# 9                              NaN                479a2e13              NaN
#
#    ...  CONTRACT_RISK_WEIGHTED_ASSETS  CONTRACT_TYPE_OF_INTEREST_REPAYMENT  \
# 0  ...                           1.00                                  NaN
# 1  ...                          74.17                                  NaN
# 2  ...                          74.77                             100003.0
# 3  ...                           0.99                                  NaN
# 4  ...                          74.30                             100002.0
# 5  ...                           0.98                                  NaN
# 6  ...                           1.00                                  NaN
# 7  ...                           1.03                                  NaN
# 8  ...                           1.04                                  NaN
# 9  ...                           1.00                                  0.0
#
#    BORROWER_BIRTH_YEAR  BORROWER_CITIZENSHIP  BORROWER_COUNTRY  \
# 0               1217.0                  98.0              98.0
# 1                  NaN                   NaN               NaN
# 2               1199.0                  98.0              98.0
# 3               1221.0                  98.0              98.0
# 4               1260.0                  98.0              98.0
# 5               1204.0                  98.0              98.0
# 6                  NaN                   NaN               NaN
# 7               1255.0                  98.0              98.0
# 8               1234.0                  98.0              98.0
# 9               1228.0                  98.0              98.0
#
#    BORROWER_COUNTY  BORROWER_TYPE_OF_CUSTOMER  BORROWER_TYPE_OF_SETTLEMENT  \
# 0             20.0                          A                          NaN
# 1              NaN                          A                          NaN
# 2            179.0                          A                          7.0
# 3              NaN                          A                          NaN
# 4            178.0                          A                          1.0
# 5              NaN                          A                          NaN
# 6              NaN                          A                          NaN
# 7              4.0                          A                          NaN
# 8              NaN                          A                          NaN
# 9              3.0                          A                          NaN
#
#   TARGET_EVENT  TARGET_EVENT_DAY
# 0            -               NaN
# 1            -               NaN
# 2            -               NaN
# 3            -               NaN
# 4            -               NaN
# 5            -               NaN
# 6            -               NaN
# 7            -               NaN
# 8            -               NaN
# 9            -               NaN
#
# [10 rows x 34 columns]

# %%
duplikalt_sorok = df[df.duplicated(subset=['CONTRACT_ID','BORROWER_ID','CONTRACT_BANK_ID'])]

# %%
len(duplikalt_sorok)
# Out:
# 0

# %%
col=['CONTRACT_CREDIT_LOSS', 'TARGET_EVENT']
df2=df[col]
df2.head(100)
# Out:
#     CONTRACT_CREDIT_LOSS TARGET_EVENT
# 0                    0.0            -
# 1                    0.0            -
# 2                16350.0            -
# 3                    0.0            -
# 4                 2395.0            -
# ..                   ...          ...
# 95                   0.0            -
# 96               25821.0            -
# 97                   0.0            -
# 98                   0.0            -
# 99                   0.0            -
#
# [100 rows x 2 columns]

# %% [markdown]
# First, i should prepare the borrower data, and maybe with that, i could predict certain elements  of the contract data.

# %%
nan_count=  df.isna().sum()

# %%
df['CONTRACT_FREQUENCY_TYPE'].value_counts()
# Out:
# CONTRACT_FREQUENCY_TYPE
# 479a2e13    1477500
# 2f88e16c      58702
# 87db11f5      47152
# 3265c5b7      17386
# ad534644       1616
# 89efd382        337
# 2aebe4cb         53
# bd092d5a          7
# Name: count, dtype: int64

# %%
coloumns = nan_count[nan_count/data_count<=0.5].index
off_coloumns = nan_count[nan_count/data_count>0.5].index

print(len(coloumns))
print(len(off_coloumns))
# Out:
# 28
# 6

# %%
df_2=df[coloumns]

# %%
off_coloumns
# Out:
# Index(['CONTRACT_INSTALMENT_AMOUNT', 'CONTRACT_LOAN_TO_VALUE_RATIO',
#        'CONTRACT_MARKET_VALUE', 'CONTRACT_MORTGAGE_LENDING_VALUE',
#        'CONTRACT_MORTGAGE_TYPE', 'TARGET_EVENT_DAY'],
#       dtype='object')

# %% [markdown]
# #### CONTRACT_CREDIT_LOSS

# %%
df['CONTRACT_CREDIT_LOSS'].isna().sum()
# Out:
# 36154

# %%
df['CONTRACT_CREDIT_LOSS']=df['CONTRACT_CREDIT_LOSS'].fillna(0)

# %%
df.nunique()
# Out:
# CONTRACT_ID                            1274533
# BORROWER_ID                            1149851
# CONTRACT_BANK_ID                           136
# CONTRACT_CREDIT_INTERMEDIARY                 4
# CONTRACT_CREDIT_LOSS                    165007
# CONTRACT_CURRENCY                            3
# CONTRACT_DATE_OF_LOAN_AGREEMENT           1072
# CONTRACT_DEPT_SERVICE_TO_INCOME          11367
# CONTRACT_FREQUENCY_TYPE                      8
# CONTRACT_INCOME                         410880
# CONTRACT_INSTALMENT_AMOUNT               61334
# CONTRACT_INSTALMENT_AMOUNT_2            158047
# CONTRACT_INTEREST_PERIOD                  1038
# CONTRACT_INTEREST_RATE                    4322
# CONTRACT_LGD                            879303
# CONTRACT_LOAN_AMOUNT                    835480
# CONTRACT_LOAN_CONTRACT_TYPE                  8
# CONTRACT_LOAN_TO_VALUE_RATIO             11662
# CONTRACT_LOAN_TYPE                          18
# CONTRACT_MARKET_VALUE                   274389
# CONTRACT_MATURITY_DATE                   10744
# CONTRACT_MORTGAGE_LENDING_VALUE         271960
# CONTRACT_MORTGAGE_TYPE                      18
# CONTRACT_REFINANCED                          4
# CONTRACT_RISK_WEIGHTED_ASSETS            23085
# CONTRACT_TYPE_OF_INTEREST_REPAYMENT          9
# BORROWER_BIRTH_YEAR                        101
# BORROWER_CITIZENSHIP                        41
# BORROWER_COUNTRY                            53
# BORROWER_COUNTY                            199
# BORROWER_TYPE_OF_CUSTOMER                    2
# BORROWER_TYPE_OF_SETTLEMENT                  8
# TARGET_EVENT                                 3
# TARGET_EVENT_DAY                           928
# dtype: int64
